# %% [markdown]
# SUPERSTORE MARKETING CAMPAIGN DATASET ANALYSIS

# %%
## IMPORTING ALL THE RELEVANT LIBRARY IN JUPYTER NOTEBOOK

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
from pandas_visual_analysis import VisualAnalysis

# %%
## IMPORTING THE DATASET IN JUPYTER LAB FOR DATA PREPARATION

# %%
sales_df=pd.read_csv('superstore_data.csv')

# %%
## READING THE DATASET

# %%
sales_df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
## FIRING BASIC PANDAS COMMAND FOR FURTHER DATA READING PROCESS

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
## FOR TOP 5 RECORD IN A DATASET

# %%
sales_df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
## FOR THE LAST 5 RECORD IN A DATASET

# %%
sales_df.tail()
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 2235         1    7/3/2013       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0   3/12/2012       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2    1/9/2012       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %%
## CHECKING THE DATATYPES

# %%
sales_df.dtypes
# Out:
# Id                       int64
# Year_Birth               int64
# Education               object
# Marital_Status          object
# Income                 float64
# Kidhome                  int64
# Teenhome                 int64
# Dt_Customer             object
# Recency                  int64
# MntWines                 int64
# MntFruits                int64
# MntMeatProducts          int64
# MntFishProducts          int64
# MntSweetProducts         int64
# MntGoldProds             int64
# NumDealsPurchases        int64
# NumWebPurchases          int64
# NumCatalogPurchases      int64
# NumStorePurchases        int64
# NumWebVisitsMonth        int64
# Response                 int64
# Complain                 int64
# dtype: object

# %%
## CHECKING THE SATISTICAL CALCUATION OF OUR DATASET

# %%
sales_df.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %%
sales_df.isnull()
# Out:
#          Id  Year_Birth  Education  Marital_Status  Income  Kidhome  Teenhome  \
# 0     False       False      False           False   False    False     False
# 1     False       False      False           False   False    False     False
# 2     False       False      False           False   False    False     False
# 3     False       False      False           False   False    False     False
# 4     False       False      False           False   False    False     False
# ...     ...         ...        ...             ...     ...      ...       ...
# 2235  False       False      False           False   False    False     False
# 2236  False       False      False           False   False    False     False
# 2237  False       False      False           False   False    False     False
# 2238  False       False      False           False   False    False     False
# 2239  False       False      False           False   False    False     False
#
# ...

# %%
sns.barplot(data=sales_df,x='Marital_Status',y='Income')
# Out:
# <AxesSubplot: xlabel='Marital_Status', ylabel='Income'>

# %%
sns.heatmap(sales_df.isnull(), cbar=False)
# Out:
# <AxesSubplot: >

# %%
## WE CAN CLEARLY SEE THAT INCOME COLUMN HAVE OME NULL VALUES REST ARE FINE IN TERMS OF NULL VALUES

# %%
sales_df['Income'].mode()
# Out:
# 0    7500.0
# Name: Income, dtype: float64

# %%
## CHECKING THE MODE OF THE COLUMN THAT HAVE NULL VALUES

# %%
sales_df['Income'].mode()[0]
# Out:
# 7500.0

# %%
sales_df.isnull().sum()
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
## REPLACING THE NULL VALUES WITH MODE

# %%
sales_df['Income'].fillna(sales_df['Income'].mode()[0],inplace=True)

# %%
## THE NULL VALUES IS REPLACED  BY THE MODE

# %%
sales_df['Income'].isnull().sum()
# Out:
# 0

# %%
sales_df['Income'].value_counts()
# Out:
# 7500.0     36
# 35860.0     4
# 46098.0     3
# 39922.0     3
# 67445.0     3
#            ..
# 46086.0     1
# 42243.0     1
# 35788.0     1
# 36026.0     1
# 94871.0     1
# Name: Income, Length: 1974, dtype: int64

# %%
## CHECKING THE COLUMNS OF THE DATASET

# %%
sales_df.columns
# Out:
# Index(['Id', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Response', 'Complain'],
#       dtype='object')

# %%
## PLOTTING THE BOXPLOT TO CHECK ANY OUTLIERS IN THE DATASET OR NOT

# %%
sns.boxplot(data=sales_df,x='Education',y='NumCatalogPurchases')
# Out:
# <AxesSubplot: xlabel='Education', ylabel='NumCatalogPurchases'>

# %%
## WITH THIS BOXPPLOT WE CAN CLARLY SEE THAT IN GRADUATION AND PHD CATEGORY SOME OF THE PURCHASE ARE BEYOND THE EXPECTATION

# %%
Df_edu = 100*sales_df['Education'].value_counts()/len(sales_df['Education'])

# %%
Df_edu
# Out:
# Graduation    50.312500
# PhD           21.696429
# Master        16.517857
# 2n Cycle       9.062500
# Basic          2.410714
# Name: Education, dtype: float64

# %%
## WITH ABOVE WE CAN CLEARLY SEE THAT WE HAVE ALMOST 50% CANDIDATE WHO IS FROM GRADUATION CATEGORY

# %%
sales_df.dtypes
# Out:
# Id                       int64
# Year_Birth               int64
# Education               object
# Marital_Status          object
# Income                 float64
# Kidhome                  int64
# Teenhome                 int64
# Dt_Customer             object
# Recency                  int64
# MntWines                 int64
# MntFruits                int64
# MntMeatProducts          int64
# MntFishProducts          int64
# MntSweetProducts         int64
# MntGoldProds             int64
# NumDealsPurchases        int64
# NumWebPurchases          int64
# NumCatalogPurchases      int64
# NumStorePurchases        int64
# NumWebVisitsMonth        int64
# Response                 int64
# Complain                 int64
# dtype: object

# %%
sales_df['Education'].value_counts().plot(kind='barh', figsize=(8, 6))
plt.xlabel("Df_edu", labelpad=14)
plt.ylabel("Complain", labelpad=14)
plt.title("Count of Complain Registered By Different Category", y=1.02);

# %%
## WE CAN CLEARLY SEE THAT GRADUATED PEOPLE ARE THOSE WHO HAVE FIRED MAXIMUM COMPLAINS

# %%
# RENAME SOME OF THE COLUMN NAME

# %%
sales_df.rename(columns={'Kidhome': 'Kids', 'Teenhome': 'Teenagers', 'Dt_Customer': 'Enrollment Date',
                         'Dt_Customer': 'Enrollment Date','MntWines':'Wines Amount'
                        }, inplace=True)

# %%
sales_df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kids  Teenagers  \
# 0      1826        1970  Graduation       Divorced  84835.0     0          0
# 1         1        1961  Graduation         Single  57091.0     0          0
# 2     10476        1958  Graduation        Married  67267.0     0          1
# 3      1386        1967  Graduation       Together  32474.0     1          1
# 4      5371        1989  Graduation         Single  21474.0     1          0
# ...     ...         ...         ...            ...      ...   ...        ...
# 2235  10142        1976         PhD       Divorced  66476.0     0          1
# 2236   5263        1977    2n Cycle        Married  31056.0     1          0
# 2237     22        1976  Graduation       Divorced  46310.0     1          0
# 2238    528        1978  Graduation        Married  65819.0     0          0
# 2239   4070        1969         PhD        Married  94871.0     0          2
#
# ...

# %%
sales_df.dtypes
# Out:
# Id                       int64
# Year_Birth               int64
# Education               object
# Marital_Status          object
# Income                 float64
# Kids                     int64
# Teenagers                int64
# Enrollment Date         object
# Recency                  int64
# Wines Amount             int64
# MntFruits                int64
# MntMeatProducts          int64
# MntFishProducts          int64
# MntSweetProducts         int64
# MntGoldProds             int64
# NumDealsPurchases        int64
# NumWebPurchases          int64
# NumCatalogPurchases      int64
# NumStorePurchases        int64
# NumWebVisitsMonth        int64
# Response                 int64
# Complain                 int64
# dtype: object

# %%
sns.boxplot(sales_df,x='NumDealsPurchases',y='Marital_Status')
# Out:
# <AxesSubplot: xlabel='NumDealsPurchases', ylabel='Marital_Status'>

# %%
## CHANGING THE DATA TYPE OF ENROLLMENT DATE COLUMN FROM OBJECT TO DATE

# %%
sales_df['Enrollment Date'] = pd.to_datetime(sales_df['Enrollment Date']).dt.date

# %%
sales_df.dtypes
# Out:
# Id                       int64
# Year_Birth               int64
# Education               object
# Marital_Status          object
# Income                 float64
# Kids                     int64
# Teenagers                int64
# Enrollment Date         object
# Recency                  int64
# Wines Amount             int64
# MntFruits                int64
# MntMeatProducts          int64
# MntFishProducts          int64
# MntSweetProducts         int64
# MntGoldProds             int64
# NumDealsPurchases        int64
# NumWebPurchases          int64
# NumCatalogPurchases      int64
# NumStorePurchases        int64
# NumWebVisitsMonth        int64
# Response                 int64
# Complain                 int64
# dtype: object

# %%
sales_df['Enrollment Date']= pd.to_datetime(sales_df['Enrollment Date'])

# %%
sales_df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kids  Teenagers  \
# 0      1826        1970  Graduation       Divorced  84835.0     0          0
# 1         1        1961  Graduation         Single  57091.0     0          0
# 2     10476        1958  Graduation        Married  67267.0     0          1
# 3      1386        1967  Graduation       Together  32474.0     1          1
# 4      5371        1989  Graduation         Single  21474.0     1          0
# ...     ...         ...         ...            ...      ...   ...        ...
# 2235  10142        1976         PhD       Divorced  66476.0     0          1
# 2236   5263        1977    2n Cycle        Married  31056.0     1          0
# 2237     22        1976  Graduation       Divorced  46310.0     1          0
# 2238    528        1978  Graduation        Married  65819.0     0          0
# 2239   4070        1969         PhD        Married  94871.0     0          2
#
# ...

# %%
## ADDING YEAR AND MONTH COLUMN FROM EXTRACTING YEAR AND MONTH FROM ENROLLMENT DATE COLUMN

# %%
sales_df['Enrolment Year'] = sales_df['Enrollment Date'].dt.year

# %%
### WE HAD CREATED A YEAR COLUMN

# %%
sales_df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kids  Teenagers  \
# 0      1826        1970  Graduation       Divorced  84835.0     0          0
# 1         1        1961  Graduation         Single  57091.0     0          0
# 2     10476        1958  Graduation        Married  67267.0     0          1
# 3      1386        1967  Graduation       Together  32474.0     1          1
# 4      5371        1989  Graduation         Single  21474.0     1          0
# ...     ...         ...         ...            ...      ...   ...        ...
# 2235  10142        1976         PhD       Divorced  66476.0     0          1
# 2236   5263        1977    2n Cycle        Married  31056.0     1          0
# 2237     22        1976  Graduation       Divorced  46310.0     1          0
# 2238    528        1978  Graduation        Married  65819.0     0          0
# 2239   4070        1969         PhD        Married  94871.0     0          2
#
# ...

# %%
## WE ARE GOING TO CREATE A MONTH COLUMN AND STORE MONTH VALUES FROM ENROLLMENT DATE COLUMNS

# %%
sales_df['Enrollment Month'] =  sales_df['Enrollment Date'].dt.month

# %%
sales_df.tail(2)
# Out:
#         Id  Year_Birth   Education Marital_Status   Income  Kids  Teenagers  \
# 2238   528        1978  Graduation        Married  65819.0     0          0
# 2239  4070        1969         PhD        Married  94871.0     0          2
#
#      Enrollment Date  Recency  Wines Amount  ...  MntGoldProds  \
# 2238      2012-11-29       99           267  ...            63
# 2239      2012-01-09       99           169  ...           144
#
#       NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 2238                  1                5                    4
# 2239                  1                8                    5
#
#       NumStorePurchases  NumWebVisitsMonth  Response  Complain  \
# 2238                 10                  3         0         0
# 2239                  4                  7         1         0
#
#       Enrolment Year  Enrollment Month
# 2238            2012                11
# 2239            2012                 1
#
# [2 rows x 24 columns]

# %%
sales_df['Enrolment Year'].unique()
# Out:
# array([2014, 2013, 2012], dtype=int64)

# %%
correlation = sales_df.corr()
# Out:
# C:\Users\JAI SHREE RAM\AppData\Local\Temp\ipykernel_1476\2348536988.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = sales_df.corr()

# %%
correlation
# Out:
#                            Id  Year_Birth    Income      Kids  Teenagers  \
# Id                   1.000000    0.000028  0.010781  0.002406  -0.002580
# Year_Birth           0.000028    1.000000 -0.156165  0.230176  -0.352111
# Income               0.010781   -0.156165  1.000000 -0.425939   0.016037
# Kids                 0.002406    0.230176 -0.425939  1.000000  -0.036133
# Teenagers           -0.002580   -0.352111  0.016037 -0.036133   1.000000
# Recency             -0.046524   -0.019871 -0.009692  0.008827   0.016198
# Wines Amount        -0.022878   -0.157773  0.573236 -0.496297   0.004846
# MntFruits            0.004600   -0.017917  0.424019 -0.372581  -0.176764
# MntMeatProducts     -0.004437   -0.030872  0.568613 -0.437129  -0.261160
# MntFishProducts     -0.024475   -0.041625  0.433843 -0.387644  -0.204187
# MntSweetProducts    -0.007642   -0.018133  0.427522 -0.370673  -0.162475
# MntGoldProds        -0.013438   -0.061818  0.314771 -0.349595  -0.021725
# ...

# %%
plt.figure(figsize= (15, 15))
sns.heatmap(correlation, cbar = True, square= True, fmt = '.1f', annot= True, annot_kws= {'size' : 10 }, cmap = 'Greens' )
# Out:
# <AxesSubplot: >

# %%
ax = plt.subplots(figsize=(15, 4))
sns.countplot(y="Enrolment Year", hue='Response', data=sales_df).set_title('NUMBER OF RESPONSES WE GET BY ENROLLMENT YEAR');

# %%
## CONCLUSION
## 1.WE CAN CLEARLY SEE THAT IN 2013 YEAR WE GET THE HIGHEST RESPONSE

# %%
sales_df.groupby('Complain').Recency.hist()
# Out:
# Complain
# 0    AxesSubplot(0.125,0.11;0.775x0.77)
# 1    AxesSubplot(0.125,0.11;0.775x0.77)
# Name: Recency, dtype: object

# %%
## CONCLUSION 
## 1. HERE IN RECENCY =  THE NUMBER OF DAYS SINCE LAST PURCHASE 
## IT SHOWS THAT FROM LAST PURCHASES THE COMPLAINS REGISTERED OR NOT FROM THE ITEMS IS PURCHASED

# %%
## CREATING SOME VISUALS BY USING PANDAS VISUAL ANALYSIS LIBRARY

# %%
VisualAnalysis(sales_df)
# Out:
# ...
# C:\Users\JAI SHREE RAM\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas_visual_analysis\widgets\brush_summary.py:116: RuntimeWarning:
#
# invalid value encountered in double_scalars
